# %%
import pandas as pd

# %%
bookings = pd.read_csv('2_bookings.csv', sep = ';')
bookings_head = bookings.head(7)

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
for column in bookings:
    bookings.rename(columns = {column: column.lower().replace(' ','_')}, inplace = 1)

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.query('is_canceled == 0')\
.groupby('country')\
.aggregate({'hotel':'count'})\
.sort_values('hotel', ascending = False).head(5)
# Out:
#          hotel
# country
# PRT      21071
# GBR       9676
# FRA       8481
# ESP       6391
# DEU       6069

# %%
bookings.groupby('hotel').aggregate({'stays_total_nights':'mean'})
# Out:
#               stays_total_nights
# hotel
# City Hotel              2.978142
# Resort Hotel            4.318547

# %%
bookings.query('assigned_room_type != reserved_room_type').count()
# Out:
# hotel                        14917
# is_canceled                  14917
# lead_time                    14917
# arrival_full_date            14917
# arrival_date_year            14917
# arrival_date_month           14917
# arrival_date_week_number     14917
# arrival_date_day_of_month    14917
# stays_in_weekend_nights      14917
# stays_in_week_nights         14917
# stays_total_nights           14917
# adults                       14917
# children                     14917
# babies                       14917
# meal                         14917
# country                      14699
# reserved_room_type           14917
# assigned_room_type           14917
# customer_type                14917
# reservation_status           14917
# reservation_status_date      14917
# dtype: int64

# %%
bookings.query('(arrival_date_year == 2016 )| (arrival_date_year == 2017)')\
.groupby(['arrival_date_year','arrival_date_month'])\
.aggregate({'hotel':'count'})\
.sort_values('hotel', ascending = False)
# Out:
#                                       hotel
# arrival_date_year arrival_date_month
# 2017              May                  6313
# 2016              October              6203
# 2017              April                5661
#                   June                 5647
# 2016              May                  5478
#                   April                5428
#                   September            5394
# 2017              July                 5313
# 2016              June                 5292
#                   August               5063
# 2017              March                4970
#                   August               4925
# 2016              March                4824
#                   July                 4572
#                   November             4454
# 2017              February             4177
# 2016              February             3891
#                   December             3860
# 2017              January              3681
# ...

# %%
bookings.query("(hotel == 'Resort Hotel') & (is_canceled == 1)")\
.groupby(['arrival_date_year','arrival_date_month'])['is_canceled']\
.value_counts()
# Out:
# arrival_date_year  arrival_date_month  is_canceled
# 2015               August              1              366
#                    December            1              305
#                    July                1              320
#                    November            1              185
#                    October             1              411
#                    September           1              551
# 2016               April               1              522
#                    August              1              578
#                    December            1              326
#                    February            1              407
#                    January             1              119
#                    July                1              456
#                    June                1              376
#                    March               1              369
#                    May                 1              479
# ...

# %%
subset = bookings.query("(hotel == 'Resort Hotel') & (is_canceled == 1)")

# %%
bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
bookings['total_kids'] = bookings.children + bookings.babies

# %%
bookings.groupby('hotel').aggregate({'total_kids':'mean'})
# Out:
#               total_kids
# hotel
# City Hotel      0.096311
# Resort Hotel    0.142586

# %%
bookings['has_kids'] = False

# %%
for index in bookings.index:
    if bookings.iloc[index,-2] > 0:
        bookings.iloc[index,-1] = True

# %%
bookings.shape
# Out:
# (119390, 23)

# %%
by_kids_canc = bookings.groupby(['has_kids' ,'is_canceled'], as_index = False)\
    .agg({'customer_type':'count'})

# %%
by_kids_canc
# Out:
#    has_kids  is_canceled  customer_type
# 0     False            0          69093
# 1     False            1          40965
# 2      True            0           6073
# 3      True            1           3259

# %%
by_kids = bookings.groupby(['has_kids'])\
    .agg({'customer_type':'count'})\
    .rename(columns = {'customer_type':'Total'})

# %%
total = by_kids_canc.merge(by_kids, on = 'has_kids', how = 'inner')

# %%
total['Perc'] = (total['customer_type'] / total['Total']).mul(100)

# %%
total
# Out:
#   has_kids  is_canceled  customer_type   Total       Perc
# 0    False            0          69093  110058  62.778717
# 1    False            1          40965  110058  37.221283
# 2     True            0           6073    9332  65.077154
# 3     True            1           3259    9332  34.922846
